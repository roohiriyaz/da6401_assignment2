# %%
# !pip install -q wandb

# %%
import wandb

# %%
wandb.login(key="8b9afebd4705d9e357dd7b2fa957f97e19705bf1")
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# True

# %%
import os
import wandb
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import StratifiedShuffleSplit

# %%
class CNN(nn.Module):
    def __init__(self, num_classes, in_channels=3, base_filter=32, filter_mode='same',
                 activation='relu', dropout=0.0, use_batchnorm=False):
        super(CNN, self).__init__()

        ACTIVATIONS = {
            'relu': nn.ReLU(),
            'gelu': nn.GELU(),
            'silu': nn.SiLU(),
            'mish': nn.Mish()
        }
        act_fn = ACTIVATIONS[activation]

        # filter organization strategy
        if filter_mode == 'same':
            filters = [base_filter] * 3
        elif filter_mode == 'double':
            filters = [base_filter * (2 ** i) for i in range(3)]
        elif filter_mode == 'half':
            filters = [max(8, base_filter // (2 ** i)) for i in range(3)]  # avoid going below 8
        else:
            filters = [base_filter] * 3

        layers = []
        input_channels = in_channels
        for out_channels in filters:
            layers.append(nn.Conv2d(input_channels, out_channels, kernel_size=3, padding=1))
            if use_batchnorm:
                layers.append(nn.BatchNorm2d(out_channels))
            layers.append(act_fn)
            layers.append(nn.MaxPool2d(kernel_size=2, stride=2))
            if dropout > 0:
                layers.append(nn.Dropout2d(dropout))
            input_channels = out_channels  # <-- FIXED HERE

        self.features = nn.Sequential(*layers)
        self.pool = nn.AdaptiveAvgPool2d((1, 1))
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_channels, 128),  # <-- FIXED HERE
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.pool(x)
        x = self.classifier(x)
        return x

# %% [raw]
# print('num classes', num_classes)

# %%
def get_dataloaders(batch_size=64, augment=False):
    train_dir = '/kaggle/input/nature/inaturalist_12K/train'

    base_transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.5]*3, [0.5]*3)
    ])

    if augment:
        transform = transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.RandomRotation(10),
            transforms.RandomResizedCrop(224),
            transforms.ColorJitter(brightness=0.2, contrast=0.2),
            *base_transform.transforms
        ])
    else:
        transform = base_transform

    full_dataset = datasets.ImageFolder(root=train_dir, transform=transform)
    targets = [sample[1] for sample in full_dataset]


    sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
    train_idx, val_idx = next(sss.split(list(range(len(targets))), targets))

    train_dataset = Subset(full_dataset, train_idx)
    val_dataset = Subset(full_dataset, val_idx)

    val_dataset.dataset.transform = base_transform

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    num_classes = len(full_dataset.classes)

    return train_loader, val_loader, num_classes

# %%
def train_model(config=None):
    with wandb.init(config=config):
        config = wandb.config
        run_name = f"act:{config.activation}_fm:{config.filter_mode}_do:{config.dropout}_bn:{config.batchnorm}_aug:{config.augment}"
        wandb.run.name = run_name
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        train_loader, val_loader, num_classes = get_dataloaders(config.batch_size, config.augment)
        model = CNN(
            in_channels=3,
            num_classes=num_classes,
            base_filter=config.base_filter,
            filter_mode=config.filter_mode,
            activation=config.activation,
            dropout=config.dropout,
            use_batchnorm=config.batchnorm
        ).to(device)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)

        for epoch in range(config.epochs):
            model.train()
            running_loss, correct, total = 0.0, 0, 0
            for images, labels in train_loader:
                images, labels = images.to(device), labels.to(device)
                optimizer.zero_grad()
                outputs = model(images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                running_loss += loss.item() * images.size(0)
                correct += (outputs.argmax(1) == labels).sum().item()
                total += labels.size(0)

            train_acc = correct / total
            train_loss = running_loss / total

            # Validation
            model.eval()
            val_correct, val_total = 0, 0
            with torch.no_grad():
                for images, labels in val_loader:
                    images, labels = images.to(device), labels.to(device)
                    outputs = model(images)
                    val_correct += (outputs.argmax(1) == labels).sum().item()
                    val_total += labels.size(0)

            val_acc = val_correct / val_total
            wandb.log({
                "epoch": epoch + 1,
                "train_loss": train_loss,
                "train_accuracy": train_acc,
                "val_accuracy": val_acc
            })

# %%
sweep_config = {
    'method': 'bayes',
    'metric': {'name': 'val_accuracy', 'goal': 'maximize'},
    'parameters': {
        'epochs': {'values': [20]},
        'batch_size': {'values': [32]},
        'learning_rate': {'values': [0.001]},
        'dropout': {'values': [0.2, 0.3]},
        'activation': {'values': ['relu', 'gelu', 'silu', 'mish']},
        'base_filter': {'values': [32]},
        'filter_mode': {'values': ['same', 'double', 'half']},
        'batchnorm': {'values': [True, False]},
        'augment': {'values': [True, False]},
    }
}

# 🎯 Sweep initialization
sweep_id = wandb.sweep(sweep_config, project="iNaturalist-Sweep-Final")
wandb.agent(sweep_id, function=train_model, count=20)
# Out:
# Create sweep with ID: gbv3ri8z
# Sweep URL: https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z
# wandb: Agent Starting Run: cola3wlg with config:
# wandb: 	activation: relu
# wandb: 	augment: False
# wandb: 	base_filter: 32
# wandb: 	batch_size: 32
# wandb: 	batchnorm: True
# wandb: 	dropout: 0.2
# wandb: 	epochs: 20
# wandb: 	filter_mode: double
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250419_082427-cola3wlg</code>
# Syncing run <strong><a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/cola3wlg' target="_blank">serene-sweep-1</a></strong> to <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View project at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a>
#  View sweep at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View run at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/cola3wlg' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/cola3wlg</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▄▄▄▅▅▆▆▇▆▇▇▇▇▇█████</td></tr><tr><td>train_loss</td><td>█▆▅▅▄▄▃▃▃▃▂▃▂▂▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▂▂▁▄▄▄▅▅▅▆▅▆▅▆▇▆▇▆█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_accuracy</td><td>0.27253</td></tr><tr><td>train_loss</td><td>2.01504</td></tr><tr><td>val_accuracy</td><td>0.3145</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">act:relu_fm:double_do:0.2_bn:True_aug:False</strong> at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/cola3wlg' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/cola3wlg</a><br> View project at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250419_082427-cola3wlg/logs</code>
# wandb: Agent Starting Run: lyake3fs with config:
# wandb: 	activation: mish
# wandb: 	augment: False
# wandb: 	base_filter: 32
# wandb: 	batch_size: 32
# wandb: 	batchnorm: True
# wandb: 	dropout: 0.2
# wandb: 	epochs: 20
# wandb: 	filter_mode: double
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250419_090843-lyake3fs</code>
# Syncing run <strong><a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/lyake3fs' target="_blank">cosmic-sweep-2</a></strong> to <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View project at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a>
#  View sweep at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View run at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/lyake3fs' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/lyake3fs</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▃▃▄▅▅▅▆▆▆▆▇▆▇▇▇▇█▇█</td></tr><tr><td>train_loss</td><td>█▆▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▄▅▅▄▆▆▅▆▇▇▅▇███▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_accuracy</td><td>0.28854</td></tr><tr><td>train_loss</td><td>1.98269</td></tr><tr><td>val_accuracy</td><td>0.304</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">act:mish_fm:double_do:0.2_bn:True_aug:False</strong> at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/lyake3fs' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/lyake3fs</a><br> View project at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250419_090843-lyake3fs/logs</code>
# wandb: Agent Starting Run: 6fude6zm with config:
# wandb: 	activation: mish
# wandb: 	augment: True
# wandb: 	base_filter: 32
# wandb: 	batch_size: 32
# wandb: 	batchnorm: False
# wandb: 	dropout: 0.3
# wandb: 	epochs: 20
# wandb: 	filter_mode: same
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250419_095254-6fude6zm</code>
# Syncing run <strong><a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/6fude6zm' target="_blank">giddy-sweep-3</a></strong> to <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View project at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a>
#  View sweep at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View run at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/6fude6zm' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/6fude6zm</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▅▅▆▆▇▆▇▇▇▇▇▇█▇▇▇██▇</td></tr><tr><td>train_loss</td><td>█▅▄▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▂▄▃▃▅▆▇▅▆▆▇██▇▆█▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_accuracy</td><td>0.25153</td></tr><tr><td>train_loss</td><td>2.06522</td></tr><tr><td>val_accuracy</td><td>0.2845</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">act:mish_fm:same_do:0.3_bn:False_aug:True</strong> at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/6fude6zm' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/6fude6zm</a><br> View project at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250419_095254-6fude6zm/logs</code>
# wandb: Agent Starting Run: e4wqzvgx with config:
# wandb: 	activation: silu
# wandb: 	augment: False
# wandb: 	base_filter: 32
# wandb: 	batch_size: 32
# wandb: 	batchnorm: False
# wandb: 	dropout: 0.3
# wandb: 	epochs: 20
# wandb: 	filter_mode: same
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250419_103439-e4wqzvgx</code>
# Syncing run <strong><a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/e4wqzvgx' target="_blank">genial-sweep-4</a></strong> to <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View project at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a>
#  View sweep at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View run at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/e4wqzvgx' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/e4wqzvgx</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▄▅▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇█</td></tr><tr><td>train_loss</td><td>█▅▅▄▃▃▃▂▃▂▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▃▃▄▆▆▆▆▆▆▅▇▆▇▇▇▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_accuracy</td><td>0.26216</td></tr><tr><td>train_loss</td><td>2.05243</td></tr><tr><td>val_accuracy</td><td>0.293</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">act:silu_fm:same_do:0.3_bn:False_aug:False</strong> at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/e4wqzvgx' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/e4wqzvgx</a><br> View project at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250419_103439-e4wqzvgx/logs</code>
# wandb: Agent Starting Run: v0ggwvyh with config:
# wandb: 	activation: relu
# wandb: 	augment: False
# wandb: 	base_filter: 32
# wandb: 	batch_size: 32
# wandb: 	batchnorm: False
# wandb: 	dropout: 0.3
# wandb: 	epochs: 20
# wandb: 	filter_mode: half
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250419_111609-v0ggwvyh</code>
# Syncing run <strong><a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/v0ggwvyh' target="_blank">major-sweep-5</a></strong> to <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View project at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a>
#  View sweep at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View run at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/v0ggwvyh' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/v0ggwvyh</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▃▄▅▆▆▆▆▇▇▇▇▇▇▇█████</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▄▄▃▃▃▃▂▂▂▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▅▅▅▅▇▇▆█▇▇█▇▇▇██▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_accuracy</td><td>0.19965</td></tr><tr><td>train_loss</td><td>2.17031</td></tr><tr><td>val_accuracy</td><td>0.199</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">act:relu_fm:half_do:0.3_bn:False_aug:False</strong> at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/v0ggwvyh' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/v0ggwvyh</a><br> View project at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250419_111609-v0ggwvyh/logs</code>
# wandb: Agent Starting Run: htiia9xa with config:
# wandb: 	activation: mish
# wandb: 	augment: False
# wandb: 	base_filter: 32
# wandb: 	batch_size: 32
# wandb: 	batchnorm: False
# wandb: 	dropout: 0.2
# wandb: 	epochs: 20
# wandb: 	filter_mode: half
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250419_115644-htiia9xa</code>
# Syncing run <strong><a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/htiia9xa' target="_blank">graceful-sweep-6</a></strong> to <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View project at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a>
#  View sweep at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View run at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/htiia9xa' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/htiia9xa</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▄▅▆▆▇▆▇▇▇▇▇▇███████</td></tr><tr><td>train_loss</td><td>█▅▄▄▃▃▃▂▂▂▂▂▂▁▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▃▃▄▂▄▅▅▅▇▆▇▆▆▇▆█▆▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_accuracy</td><td>0.25003</td></tr><tr><td>train_loss</td><td>2.06659</td></tr><tr><td>val_accuracy</td><td>0.251</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">act:mish_fm:half_do:0.2_bn:False_aug:False</strong> at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/htiia9xa' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/htiia9xa</a><br> View project at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250419_115644-htiia9xa/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: qopeuqlo with config:
# wandb: 	activation: silu
# wandb: 	augment: False
# wandb: 	base_filter: 32
# wandb: 	batch_size: 32
# wandb: 	batchnorm: True
# wandb: 	dropout: 0.3
# wandb: 	epochs: 20
# wandb: 	filter_mode: double
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250419_123740-qopeuqlo</code>
# Syncing run <strong><a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/qopeuqlo' target="_blank">whole-sweep-7</a></strong> to <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View project at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a>
#  View sweep at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View run at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/qopeuqlo' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/qopeuqlo</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▃▄▅▅▅▆▆▆▇▇▇▇▆▇▇▇███</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▄▄▃▃▃▂▂▂▂▂▂▁▁▁▂</td></tr><tr><td>val_accuracy</td><td>▁▃▄▅▆▅▄▅▄▆▆▇▇▆▇▇▆▇█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_accuracy</td><td>0.26828</td></tr><tr><td>train_loss</td><td>2.04383</td></tr><tr><td>val_accuracy</td><td>0.294</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">act:silu_fm:double_do:0.3_bn:True_aug:False</strong> at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/qopeuqlo' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/qopeuqlo</a><br> View project at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250419_123740-qopeuqlo/logs</code>
# wandb: Agent Starting Run: ps9bju22 with config:
# wandb: 	activation: relu
# wandb: 	augment: False
# wandb: 	base_filter: 32
# wandb: 	batch_size: 32
# wandb: 	batchnorm: False
# wandb: 	dropout: 0.3
# wandb: 	epochs: 20
# wandb: 	filter_mode: half
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250419_132148-ps9bju22</code>
# Syncing run <strong><a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/ps9bju22' target="_blank">crimson-sweep-8</a></strong> to <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View project at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a>
#  View sweep at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View run at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/ps9bju22' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/ps9bju22</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▃▃▅▆▆▇▇▇▇▇▇▇▇█▇▇███</td></tr><tr><td>train_loss</td><td>█▇▆▅▃▃▃▂▂▃▂▂▂▂▁▁▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▅▆▆▆▆▆█▇▇▇▇▇▇█████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_accuracy</td><td>0.19577</td></tr><tr><td>train_loss</td><td>2.16703</td></tr><tr><td>val_accuracy</td><td>0.2265</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">act:relu_fm:half_do:0.3_bn:False_aug:False</strong> at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/ps9bju22' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/ps9bju22</a><br> View project at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250419_132148-ps9bju22/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: ku6j10fa with config:
# wandb: 	activation: relu
# wandb: 	augment: False
# wandb: 	base_filter: 32
# wandb: 	batch_size: 32
# wandb: 	batchnorm: False
# wandb: 	dropout: 0.2
# wandb: 	epochs: 20
# wandb: 	filter_mode: double
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250419_140249-ku6j10fa</code>
# Syncing run <strong><a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/ku6j10fa' target="_blank">lively-sweep-9</a></strong> to <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View project at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a>
#  View sweep at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View run at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/ku6j10fa' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/ku6j10fa</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▃▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▆▅▅▅▄▄▄▃▃▃▂▂▂▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▄▃▄▄▆▅▆▆▆▇▆▇▇▆▇█▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_accuracy</td><td>0.29041</td></tr><tr><td>train_loss</td><td>1.98712</td></tr><tr><td>val_accuracy</td><td>0.3125</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">act:relu_fm:double_do:0.2_bn:False_aug:False</strong> at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/ku6j10fa' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/ku6j10fa</a><br> View project at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250419_140249-ku6j10fa/logs</code>
# wandb: Agent Starting Run: 0x0g7wk0 with config:
# wandb: 	activation: mish
# wandb: 	augment: True
# wandb: 	base_filter: 32
# wandb: 	batch_size: 32
# wandb: 	batchnorm: True
# wandb: 	dropout: 0.3
# wandb: 	epochs: 20
# wandb: 	filter_mode: same
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250419_144601-0x0g7wk0</code>
# Syncing run <strong><a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/0x0g7wk0' target="_blank">confused-sweep-10</a></strong> to <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View project at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a>
#  View sweep at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View run at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/0x0g7wk0' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/0x0g7wk0</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▃▄▅▆▆▆▆▆▇▇▇▇▇███▇██</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▃▃▂▂▂▂▂▂▁▁▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▃▃▆▅▆▅▇▆▅▆▆▇▇▆▇█▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_accuracy</td><td>0.25828</td></tr><tr><td>train_loss</td><td>2.05728</td></tr><tr><td>val_accuracy</td><td>0.286</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">act:mish_fm:same_do:0.3_bn:True_aug:True</strong> at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/0x0g7wk0' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/0x0g7wk0</a><br> View project at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250419_144601-0x0g7wk0/logs</code>
# wandb: Agent Starting Run: jzho9p3y with config:
# wandb: 	activation: relu
# wandb: 	augment: True
# wandb: 	base_filter: 32
# wandb: 	batch_size: 32
# wandb: 	batchnorm: False
# wandb: 	dropout: 0.3
# wandb: 	epochs: 20
# wandb: 	filter_mode: double
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250419_152905-jzho9p3y</code>
# Syncing run <strong><a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/jzho9p3y' target="_blank">zany-sweep-11</a></strong> to <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View project at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a>
#  View sweep at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View run at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/jzho9p3y' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/jzho9p3y</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▃▄▅▅▅▆▆▆▆▇▇▇▇▇██▇▇█</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▂▂▃▃▄▆▄▆▆▆▆█▇▇▇██▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_accuracy</td><td>0.26141</td></tr><tr><td>train_loss</td><td>2.05564</td></tr><tr><td>val_accuracy</td><td>0.2725</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">act:relu_fm:double_do:0.3_bn:False_aug:True</strong> at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/jzho9p3y' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/jzho9p3y</a><br> View project at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250419_152905-jzho9p3y/logs</code>
# wandb: Agent Starting Run: 06y3wv2b with config:
# wandb: 	activation: silu
# wandb: 	augment: False
# wandb: 	base_filter: 32
# wandb: 	batch_size: 32
# wandb: 	batchnorm: False
# wandb: 	dropout: 0.3
# wandb: 	epochs: 20
# wandb: 	filter_mode: double
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250419_161243-06y3wv2b</code>
# Syncing run <strong><a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/06y3wv2b' target="_blank">dulcet-sweep-12</a></strong> to <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View project at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a>
#  View sweep at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View run at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/06y3wv2b' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/06y3wv2b</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▅▅▆▆▇▆▇▇▇▇▇█▇██████</td></tr><tr><td>train_loss</td><td>█▅▄▄▃▃▃▃▂▂▂▂▁▂▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▃▄▅▅▅▆▅▆▆▆▆▆▆▆▆▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_accuracy</td><td>0.26741</td></tr><tr><td>train_loss</td><td>2.03747</td></tr><tr><td>val_accuracy</td><td>0.3085</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">act:silu_fm:double_do:0.3_bn:False_aug:False</strong> at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/06y3wv2b' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/06y3wv2b</a><br> View project at: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250419_161243-06y3wv2b/logs</code>
# wandb: Agent Starting Run: g0jrfec8 with config:
# wandb: 	activation: gelu
# wandb: 	augment: True
# wandb: 	base_filter: 32
# wandb: 	batch_size: 32
# wandb: 	batchnorm: False
# wandb: 	dropout: 0.2
# wandb: 	epochs: 20
# wandb: 	filter_mode: double
# wandb: 	learning_rate: 0.001
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250419_165618-g0jrfec8</code>
# Syncing run <strong><a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/g0jrfec8' target="_blank">brisk-sweep-13</a></strong> to <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View project at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final</a>
#  View sweep at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/sweeps/gbv3ri8z</a>
#  View run at <a href='https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/g0jrfec8' target="_blank">https://wandb.ai/roohiparveen/iNaturalist-Sweep-Final/runs/g0jrfec8</a>

# %%
test_dir = "/kaggle/input/inaturalist/inaturalist_12K/val"

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

test_dataset = datasets.ImageFolder(root=test_dir, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Quick check
print("Test samples:", len(test_dataset))
print("Classes:", test_dataset.classes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_31/4027695557.py in <cell line: 0>()
#       7 ])
#       8
# ----> 9 test_dataset = datasets.ImageFolder(root=test_dir, transform=test_transform)
#      10 test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
#      11
#
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     326         allow_empty: bool = False,
#     327     ):
# --> 328         super().__init__(
#     329             root,
#     330             loader,
#
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file, allow_empty)
#     147     ) -> None:
#     148         super().__init__(root, transform=transform, target_transform=target_transform)
# --> 149         classes, class_to_idx = self.find_classes(self.root)
#     150         samples = self.make_dataset(
#     151             self.root,
#
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/folder.py in find_classes(self, directory)
#     232             (Tuple[List[str], Dict[str, int]]): List of all classes and dictionary mapping each class to an index.
#     233         """
# --> 234         return find_classes(directory)
#     235
#     236     def __getitem__(self, index: int) -> Tuple[Any, Any]:
#
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/folder.py in find_classes(directory)
#      39     See :class:`DatasetFolder` for details.
#      40     """
# ---> 41     classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())
#      42     if not classes:
#      43         raise FileNotFoundError(f"Couldn't find any class folder in {directory}.")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/inaturalist/inaturalist_12K/val'

# %%
best_config = {
    'activation': 'gelu',
    'filter_mode': 'double',
    'dropout': 0.2,
    'batchnorm': False,
    'augment': True,
    'batch_size': 32,
    'learning_rate': 0.001,
    'epochs': 20,
    'base_filter': 32
}

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Recreate the best model
best_model = CNN(
    in_channels=3,
    num_classes=10,
    base_filter=32,  # fixed base filter
    filter_mode=best_config['filter_mode'],
    activation=best_config['activation'],
    dropout=best_config['dropout'],
    use_batchnorm=best_config['batchnorm']
).to(device)

# %%
def evaluate(model, dataloader):
    model.eval()
    correct, total = 0, 0
    all_preds = []
    all_images = []
    
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            preds = outputs.argmax(1)
            
            correct += (preds == labels).sum().item()
            total += labels.size(0)
            all_preds.extend(preds.cpu())
            all_images.extend(images.cpu())

    accuracy = correct / total
    return accuracy, all_images, all_preds

# %%
test_loader, class_names = get_test_loader(batch_size=64)
test_acc, test_images, test_preds = evaluate(best_model, test_loader)
print(f"Test Accuracy: {test_acc:.4f}")

# %%
import matplotlib.pyplot as plt

def show_prediction_grid(images, predictions, class_names, rows=10, cols=3):
    fig, axes = plt.subplots(rows, cols, figsize=(15, 25))
    for i in range(rows * cols):
        ax = axes[i // cols, i % cols]
        img = images[i]
        img = img * 0.5 + 0.5  # unnormalize
        img = img.permute(1, 2, 0).numpy()
        ax.imshow(img)
        ax.set_title(f"Pred: {class_names[predictions[i]]}", fontsize=10)
        ax.axis('off')
    
    plt.tight_layout()
    plt.suptitle("Predictions from Best Model", fontsize=16, y=1.02)
    plt.show()

show_prediction_grid(test_images, test_preds, class_names)
